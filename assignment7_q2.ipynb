# %%
# Use base python environment
# !pip install statsmodels stargazer --q

import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load data
df = pd.read_stata("assignment7.dta")

# Keep Great Britain only
df = df[df["nireland"] == 0].copy()

# Generate polynomial controls
df["y1"] = df["yobirth"] - df["yobirth"].mean()
df["y2"] = df["y1"]**2
df["y3"] = df["y1"]**3
df["y4"] = df["y1"]**4

df["a1"] = df["age"] - df["age"].mean()
df["a2"] = df["a1"]**2
df["a3"] = df["a1"]**3
df["a4"] = df["a1"]**4


def reg(formula, df=df):
    """
    Runs WLS with clustering, ensuring that weights and cluster
    groups match the rows used by the regression.
    """

    # First run OLS formula to determine which observations are used
    temp = smf.ols(formula, data=df).fit()
    used = temp.model.data.row_labels   # index of rows kept

    # Filter weights + cluster to match used rows
    df_used = df.loc[used]

    # Now run WLS with aligned weights
    model = smf.wls(formula, data=df_used, weights=df_used["wght"]).fit(
        cov_type="cluster", cov_kwds={"groups": df_used["yobirth"]}
    )

    return model

# -----------------------------------------------------
# Run all Table 1 regressions
# -----------------------------------------------------
m1 = reg("agelfted ~ drop15 + y1 + y2 + y3 + y4")
m2 = reg("agelfted ~ drop15 + y1 + y2 + y3 + y4 + a1 + a2 + a3 + a4")
m3 = reg("agelfted ~ drop15 + y1 + y2 + y3 + y4 + C(age)")

m4 = reg("learn ~ drop15 + y1 + y2 + y3 + y4")
m5 = reg("learn ~ drop15 + y1 + y2 + y3 + y4 + a1 + a2 + a3 + a4")
m6 = reg("learn ~ drop15 + y1 + y2 + y3 + y4 + C(age)")

results = [m1, m2, m3, m4, m5, m6]
model_names = [
    "FS: YOB poly",
    "FS: +Age poly",
    "FS: Age FE",
    "RF: YOB poly",
    "RF: +Age poly",
    "RF: Age FE"
]

# -----------------------------------------------------
# Print summaries for each regression
# -----------------------------------------------------
for i, model in enumerate(results):
    print("\n==============================================")
    print(f"Summary for {model_names[i]}")
    print("==============================================\n")
    print(model.summary())

# -----------------------------------------------------
# Build clean output table like Table 1
# -----------------------------------------------------
table = pd.DataFrame({
    "Model": model_names,
    "Coef_drop15": [m.params["drop15"] for m in results],
    "SE_drop15": [m.bse["drop15"] for m in results]
})

print("\n==============================================")
print("           TABLE 1 (Great Britain)")
print("==============================================\n")
print(table)
# Out:
# ==============================================
# Summary for FS: YOB poly
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:               agelfted   R-squared:                       0.050
# Model:                            WLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     4113.
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):           1.39e-41
# Time:                        22:42:24   Log-Likelihood:                -63791.
# No. Observations:               22574   AIC:                         1.276e+05
# Df Residuals:                   22568   BIC:                         1.276e+05
# Df Model:                           5
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     15.8329      0.069    229.718      0.000      15.698      15.968
# drop15         0.4693      0.067      6.991      0.000       0.338       0.601
# y1             0.0526      0.003     17.086      0.000       0.047       0.059
# y2            -0.0002      0.001     -0.324      0.746      -0.001       0.001
# y3             0.0002   2.25e-05      7.074      0.000       0.000       0.000
# y4           8.94e-06   2.36e-06      3.788      0.000    4.31e-06    1.36e-05
# ==============================================================================
# Omnibus:                      598.894   Durbin-Watson:                   0.485
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              655.767
# Skew:                           0.392   Prob(JB):                    4.00e-143
# Kurtosis:                       3.288   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
# Summary for FS: +Age poly
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:               agelfted   R-squared:                       0.050
# Model:                            WLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     2508.
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):           1.27e-40
# Time:                        22:42:24   Log-Likelihood:                -63789.
# No. Observations:               22574   AIC:                         1.276e+05
# Df Residuals:                   22564   BIC:                         1.277e+05
# Df Model:                           9
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     15.8588      0.067    237.034      0.000      15.728      15.990
# drop15         0.4690      0.066      7.139      0.000       0.340       0.598
# y1             0.0512      0.003     15.308      0.000       0.045       0.058
# y2             0.0003      0.001      0.409      0.682      -0.001       0.002
# y3             0.0001   2.71e-05      5.314      0.000    9.09e-05       0.000
# y4          6.939e-06   2.81e-06      2.468      0.014    1.43e-06    1.25e-05
# a1            -0.0129      0.006     -2.194      0.028      -0.024      -0.001
# a2            -0.0012      0.001     -1.472      0.141      -0.003       0.000
# a3          8.419e-05   4.92e-05      1.710      0.087   -1.23e-05       0.000
# a4          6.259e-06   4.07e-06      1.537      0.124   -1.72e-06    1.42e-05
# ==============================================================================
# Omnibus:                      596.906   Durbin-Watson:                   0.486
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              652.494
# Skew:                           0.392   Prob(JB):                    2.05e-142
# Kurtosis:                       3.280   Cond. No.                     2.33e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 2.33e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
# Summary for FS: Age FE
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:               agelfted   R-squared:                       0.051
# Model:                            WLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                 1.561e+10
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):          5.14e-146
# Time:                        22:42:24   Log-Likelihood:                -63785.
# No. Observations:               22574   AIC:                         1.276e+05
# Df Residuals:                   22535   BIC:                         1.280e+05
# Df Model:                          38
# Covariance Type:              cluster
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       16.6724      0.072    231.943      0.000      16.531      16.813
# C(age)[T.29]    -2.1043      0.388     -5.425      0.000      -2.865      -1.344
# C(age)[T.33]    -0.8354   1.86e-05  -4.48e+04      0.000      -0.835      -0.835
# C(age)[T.34]    -0.8455      0.055    -15.498      0.000      -0.952      -0.739
# C(age)[T.35]    -0.8775      0.108     -8.104      0.000      -1.090      -0.665
# C(age)[T.36]    -0.7051      0.045    -15.831      0.000      -0.792      -0.618
# C(age)[T.37]    -0.9419      0.076    -12.340      0.000      -1.092      -0.792
# C(age)[T.38]    -0.8717      0.047    -18.414      0.000      -0.964      -0.779
# C(age)[T.39]    -0.9105      0.061    -15.024      0.000      -1.029      -0.792
# C(age)[T.40]    -0.8650      0.058    -14.799      0.000      -0.980      -0.750
# C(age)[T.41]    -0.8467      0.056    -15.062      0.000      -0.957      -0.737
# C(age)[T.42]    -0.8247      0.051    -16.282      0.000      -0.924      -0.725
# C(age)[T.43]    -0.8954      0.036    -24.904      0.000      -0.966      -0.825
# C(age)[T.44]    -0.8006      0.063    -12.790      0.000      -0.923      -0.678
# C(age)[T.45]    -0.8030      0.086     -9.315      0.000      -0.972      -0.634
# C(age)[T.46]    -0.7339      0.063    -11.682      0.000      -0.857      -0.611
# C(age)[T.47]    -0.7606      0.090     -8.412      0.000      -0.938      -0.583
# C(age)[T.48]    -0.6976      0.069    -10.096      0.000      -0.833      -0.562
# C(age)[T.49]    -0.8246      0.078    -10.638      0.000      -0.977      -0.673
# C(age)[T.50]    -0.8098      0.088     -9.196      0.000      -0.982      -0.637
# C(age)[T.51]    -0.8410      0.059    -14.175      0.000      -0.957      -0.725
# C(age)[T.52]    -0.8600      0.051    -16.821      0.000      -0.960      -0.760
# C(age)[T.53]    -0.8807      0.075    -11.774      0.000      -1.027      -0.734
# C(age)[T.54]    -0.8538      0.056    -15.115      0.000      -0.965      -0.743
# C(age)[T.55]    -0.9032      0.062    -14.670      0.000      -1.024      -0.783
# C(age)[T.56]    -0.8311      0.064    -13.064      0.000      -0.956      -0.706
# C(age)[T.57]    -0.8944      0.059    -15.228      0.000      -1.010      -0.779
# C(age)[T.58]    -0.9943      0.051    -19.387      0.000      -1.095      -0.894
# C(age)[T.59]    -0.8847      0.053    -16.609      0.000      -0.989      -0.780
# C(age)[T.60]    -0.9819      0.066    -14.864      0.000      -1.111      -0.852
# C(age)[T.61]    -0.8623      0.065    -13.178      0.000      -0.990      -0.734
# C(age)[T.62]    -0.8596      0.062    -13.801      0.000      -0.982      -0.738
# C(age)[T.63]    -0.9633      0.058    -16.497      0.000      -1.078      -0.849
# C(age)[T.64]    -0.8630      0.078    -11.024      0.000      -1.016      -0.710
# drop15           0.4749      0.065      7.280      0.000       0.347       0.603
# y1               0.0508      0.004     14.480      0.000       0.044       0.058
# y2               0.0003      0.001      0.483      0.629      -0.001       0.001
# y3               0.0001   2.85e-05      5.213      0.000    9.28e-05       0.000
# y4            7.124e-06   2.61e-06      2.733      0.006    2.01e-06    1.22e-05
# ==============================================================================
# Omnibus:                      594.690   Durbin-Watson:                   0.486
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              649.801
# Skew:                           0.392   Prob(JB):                    7.90e-142
# Kurtosis:                       3.278   Cond. No.                     4.21e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 4.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
# Summary for RF: YOB poly
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  learn   R-squared:                       0.055
# Model:                            WLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     759.8
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):           1.25e-30
# Time:                        22:42:24   Log-Likelihood:                -19302.
# No. Observations:               13118   AIC:                         3.862e+04
# Df Residuals:                   13112   BIC:                         3.866e+04
# Df Model:                           5
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.8895      0.021    419.010      0.000       8.848       8.931
# drop15         0.0548      0.015      3.710      0.000       0.026       0.084
# y1             0.0217      0.001     19.319      0.000       0.019       0.024
# y2             0.0004      0.000      1.632      0.103   -8.14e-05       0.001
# y3         -1.576e-05   1.48e-05     -1.065      0.287   -4.48e-05    1.32e-05
# y4         -4.648e-06   1.28e-06     -3.620      0.000   -7.16e-06   -2.13e-06
# ==============================================================================
# Omnibus:                     4125.980   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18099.896
# Skew:                          -1.485   Prob(JB):                         0.00
# Kurtosis:                       7.929   Cond. No.                     1.67e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 1.67e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
# Summary for RF: +Age poly
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  learn   R-squared:                       0.133
# Model:                            WLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     533.9
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):           1.39e-30
# Time:                        22:42:24   Log-Likelihood:                -18740.
# No. Observations:               13118   AIC:                         3.750e+04
# Df Residuals:                   13108   BIC:                         3.758e+04
# Df Model:                           9
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.9488      0.028    321.189      0.000       8.894       9.003
# drop15         0.0524      0.014      3.865      0.000       0.026       0.079
# y1             0.0372      0.002     18.861      0.000       0.033       0.041
# y2             0.0014      0.000      4.502      0.000       0.001       0.002
# y3          2.134e-05   1.76e-05      1.213      0.225   -1.31e-05    5.58e-05
# y4          -3.29e-06    1.5e-06     -2.192      0.028   -6.23e-06   -3.48e-07
# a1             0.0168      0.004      3.800      0.000       0.008       0.025
# a2            -0.0021      0.001     -3.182      0.001      -0.003      -0.001
# a3          2.788e-05   3.75e-05      0.743      0.458   -4.57e-05       0.000
# a4          7.596e-07   2.84e-06      0.267      0.789   -4.81e-06    6.33e-06
# ==============================================================================
# Omnibus:                     3046.976   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7788.866
# Skew:                          -1.264   Prob(JB):                         0.00
# Kurtosis:                       5.803   Cond. No.                     2.20e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 2.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
# Summary for RF: Age FE
# ==============================================
#
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  learn   R-squared:                       0.133
# Model:                            WLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                -6.279e+12
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):               1.00
# Time:                        22:42:24   Log-Likelihood:                -18737.
# No. Observations:               13118   AIC:                         3.755e+04
# Df Residuals:                   13079   BIC:                         3.784e+04
# Df Model:                          38
# Covariance Type:              cluster
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.9165      0.031    221.977      0.000       6.855       6.978
# C(age)[T.29]     1.7734      0.118     15.028      0.000       1.542       2.005
# C(age)[T.33]     0.8934        nan        nan        nan         nan         nan
# C(age)[T.34]     1.0439      0.042     25.100      0.000       0.962       1.125
# C(age)[T.35]     1.1139      0.036     30.723      0.000       1.043       1.185
# C(age)[T.36]     1.1890      0.008    154.187      0.000       1.174       1.204
# C(age)[T.37]     1.2849      0.034     37.319      0.000       1.217       1.352
# C(age)[T.38]     1.3399      0.051     26.152      0.000       1.239       1.440
# C(age)[T.39]     1.4618      0.029     50.472      0.000       1.405       1.519
# C(age)[T.40]     1.5269      0.040     37.806      0.000       1.448       1.606
# C(age)[T.41]     1.5979      0.035     45.148      0.000       1.529       1.667
# C(age)[T.42]     1.6719      0.042     39.415      0.000       1.589       1.755
# C(age)[T.43]     1.7447      0.046     37.928      0.000       1.655       1.835
# C(age)[T.44]     1.7537      0.045     39.354      0.000       1.666       1.841
# C(age)[T.45]     1.8147      0.041     43.902      0.000       1.734       1.896
# C(age)[T.46]     1.8591      0.031     60.891      0.000       1.799       1.919
# C(age)[T.47]     1.9290      0.036     53.246      0.000       1.858       2.000
# C(age)[T.48]     1.9519      0.037     52.203      0.000       1.879       2.025
# C(age)[T.49]     1.9727      0.053     37.294      0.000       1.869       2.076
# C(age)[T.50]     1.9829      0.039     50.651      0.000       1.906       2.060
# C(age)[T.51]     2.0025      0.042     47.740      0.000       1.920       2.085
# C(age)[T.52]     2.0272      0.035     58.128      0.000       1.959       2.096
# C(age)[T.53]     2.0470      0.036     57.502      0.000       1.977       2.117
# C(age)[T.54]     2.0668      0.036     57.463      0.000       1.996       2.137
# C(age)[T.55]     2.0491      0.039     52.314      0.000       1.972       2.126
# C(age)[T.56]     2.0855      0.030     68.570      0.000       2.026       2.145
# C(age)[T.57]     2.0492      0.033     63.042      0.000       1.985       2.113
# C(age)[T.58]     2.0735      0.039     52.905      0.000       1.997       2.150
# C(age)[T.59]     2.0675      0.033     62.646      0.000       2.003       2.132
# C(age)[T.60]     2.0377      0.044     46.269      0.000       1.951       2.124
# C(age)[T.61]     2.0089      0.042     48.094      0.000       1.927       2.091
# C(age)[T.62]     2.0389      0.058     35.449      0.000       1.926       2.152
# C(age)[T.63]     1.9858      0.065     30.584      0.000       1.858       2.113
# C(age)[T.64]     1.9932      0.061     32.852      0.000       1.874       2.112
# drop15           0.0562      0.017      3.299      0.001       0.023       0.090
# y1               0.0370      0.002     17.501      0.000       0.033       0.041
# y2               0.0014      0.000      4.359      0.000       0.001       0.002
# y3            2.331e-05   1.71e-05      1.361      0.174   -1.03e-05    5.69e-05
# y4            -3.17e-06   1.44e-06     -2.205      0.027   -5.99e-06   -3.53e-07
# ==============================================================================
# Omnibus:                     3040.770   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7751.389
# Skew:                          -1.263   Prob(JB):                         0.00
# Kurtosis:                       5.793   Cond. No.                     2.29e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 2.29e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ==============================================
#            TABLE 1 (Great Britain)
# ==============================================
#
#            Model  Coef_drop15  SE_drop15
# 0   FS: YOB poly     0.469280   0.067122
# 1  FS: +Age poly     0.468970   0.065693
# 2     FS: Age FE     0.474934   0.065239
# 3   RF: YOB poly     0.054815   0.014775
# 4  RF: +Age poly     0.052390   0.013555
# 5     RF: Age FE     0.056245   0.017050
# /Users/macbookpro/Documents/DSDM/Econometrics/assignment_7/.venv/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 38, but rank is 35
#   warnings.warn('covariance of constraints does not have full '
# /Users/macbookpro/Documents/DSDM/Econometrics/assignment_7/.venv/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 38, but rank is 34
#   warnings.warn('covariance of constraints does not have full '
# /Users/macbookpro/Documents/DSDM/Econometrics/assignment_7/.venv/lib/python3.13/site-packages/statsmodels/regression/linear_model.py:1884: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
